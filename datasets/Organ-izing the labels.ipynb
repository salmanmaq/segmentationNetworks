# %% [markdown]
# ## Organ-izing the labels
# This script extracts organs from the annotated images, and reannotates all the other classes into their respective super-category

# %%
import numpy as np
import cv2
import json
import os

# %%
# Specify the dataset directories and the classes file path
data_dir = '/home/salman/pytorch/segmentationNetworks/datasets/miccaiSegRefined'
json_path = '/home/salman/pytorch/segmentationNetworks/datasets/miccaiSegClasses.json'

# Save directory
save_dir = '/home/salman/pytorch/segmentationNetworks/datasets/miccaiSegOrgans'

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
files = {x: [os.path.join(data_dir, x, 'groundtruth', f) for f in os.listdir(os.path.join(data_dir, x, 'groundtruth')) 
         if (f.endswith('.jpg') or f.endswith('.png'))]
         for x in ['train', 'test', 'trainval']}

# %%
def disentangleKey(key):
    '''
        Disentangles the key for class and labels obtained from the
        JSON file
        Returns a python dictionary of the form:
            {Class Id: RGB Color Code as numpy array}
    '''
    dKey = {}
    for i in range(len(key)):
        class_id = int(key[i]['id'])
        category = key[i]['name']
        super_category = key[i]['super-category']
        c = key[i]['color']
        c = c.split(',')
        c0 = int(c[0][1:])
        c1 = int(c[1])
        c2 = int(c[2][:-1])
        color_array = np.asarray([c0,c1,c2])
        dKey[class_id] = {'color': color_array, 'name': category, 'super_category': super_category}

    return dKey

# %%
# Get the classes RGB key
classes = json.load(open(json_path))['classes']
key = disentangleKey(classes)

# %%
# Iterate over all images to smooth them
x = ['train', 'test', 'trainval']
for i in range(len(files)):
    folder = files[x[i]]
    save_sub_dir = os.path.join(save_dir, x[i], 'groundtruth')
    if not os.path.exists(save_sub_dir):
        os.makedirs(save_sub_dir)
        
    for j in range(len(folder)):
        img = cv2.imread(folder[j])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Iterate over all categories
        for k in range(len(key)):
            rgb = key[k]['color']
            mask = np.all(img == rgb, axis=2)
            
            # Make all the instruments a single category
            if key[k]['super_category'] == 'instrument':
                img[mask] = np.asarray([0,85,170])

            # Make fluids and artery part of the gall-bladder
            if key[k]['super_category'] == 'fluid':
                img[mask] = np.asarray([85,170,255])
        
        # Save the image
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        file_name = folder[j].split('/')[-1].split('.')[0] + '.png'
        save_path = os.path.join(save_sub_dir, file_name)
        cv2.imwrite(save_path, img)
        print('Image: [%d]/[%d]: Folder: [%d]/[%d]' % (j+1, len(folder), i+1, len(files)))
# Out:
# Image: [1]/[245]: Folder: [1]/[3]
# Image: [2]/[245]: Folder: [1]/[3]
# Image: [3]/[245]: Folder: [1]/[3]
# Image: [4]/[245]: Folder: [1]/[3]
# Image: [5]/[245]: Folder: [1]/[3]
# Image: [6]/[245]: Folder: [1]/[3]
# Image: [7]/[245]: Folder: [1]/[3]
# Image: [8]/[245]: Folder: [1]/[3]
# Image: [9]/[245]: Folder: [1]/[3]
# Image: [10]/[245]: Folder: [1]/[3]
# Image: [11]/[245]: Folder: [1]/[3]
# Image: [12]/[245]: Folder: [1]/[3]
# Image: [13]/[245]: Folder: [1]/[3]
# Image: [14]/[245]: Folder: [1]/[3]
# Image: [15]/[245]: Folder: [1]/[3]
# Image: [16]/[245]: Folder: [1]/[3]
# Image: [17]/[245]: Folder: [1]/[3]
# Image: [18]/[245]: Folder: [1]/[3]
# Image: [19]/[245]: Folder: [1]/[3]
# Image: [20]/[245]: Folder: [1]/[3]
# Image: [21]/[245]: Folder: [1]/[3]
# Image: [22]/[245]: Folder: [1]/[3]
# Image: [23]/[245]: Folder: [1]/[3]
# Image: [24]/[245]: Folder: [1]/[3]
# Image: [25]/[245]: Folder: [1]/[3]
# Image: [26]/[245]: Folder: [1]/[3]
# Image: [27]/[245]: Folder: [1]/[3]
# Image: [28]/[245]: Folder: [1]/[3]
# Image: [29]/[245]: Folder: [1]/[3]
# Image: [30]/[245]: Folder: [1]/[3]
# Image: [31]/[245]: Folder: [1]/[3]
# Image: [32]/[245]: Folder: [1]/[3]
# Image: [33]/[245]: Folder: [1]/[3]
# Image: [34]/[245]: Folder: [1]/[3]
# Image: [35]/[245]: Folder: [1]/[3]
# Image: [36]/[245]: Folder: [1]/[3]
# Image: [37]/[245]: Folder: [1]/[3]
# Image: [38]/[245]: Folder: [1]/[3]
# Image: [39]/[245]: Folder: [1]/[3]
# Image: [40]/[245]: Folder: [1]/[3]
# Image: [41]/[245]: Folder: [1]/[3]
# Image: [42]/[245]: Folder: [1]/[3]
# Image: [43]/[245]: Folder: [1]/[3]
# Image: [44]/[245]: Folder: [1]/[3]
# Image: [45]/[245]: Folder: [1]/[3]
# Image: [46]/[245]: Folder: [1]/[3]
# Image: [47]/[245]: Folder: [1]/[3]
# Image: [48]/[245]: Folder: [1]/[3]
# Image: [49]/[245]: Folder: [1]/[3]
# Image: [50]/[245]: Folder: [1]/[3]
# Image: [51]/[245]: Folder: [1]/[3]
# Image: [52]/[245]: Folder: [1]/[3]
# Image: [53]/[245]: Folder: [1]/[3]
# Image: [54]/[245]: Folder: [1]/[3]
# Image: [55]/[245]: Folder: [1]/[3]
# Image: [56]/[245]: Folder: [1]/[3]
# Image: [57]/[245]: Folder: [1]/[3]
# Image: [58]/[245]: Folder: [1]/[3]
# Image: [59]/[245]: Folder: [1]/[3]
# Image: [60]/[245]: Folder: [1]/[3]
# Image: [61]/[245]: Folder: [1]/[3]
# Image: [62]/[245]: Folder: [1]/[3]
# Image: [63]/[245]: Folder: [1]/[3]
# Image: [64]/[245]: Folder: [1]/[3]
# Image: [65]/[245]: Folder: [1]/[3]
# Image: [66]/[245]: Folder: [1]/[3]
# Image: [67]/[245]: Folder: [1]/[3]
# Image: [68]/[245]: Folder: [1]/[3]
# Image: [69]/[245]: Folder: [1]/[3]
# Image: [70]/[245]: Folder: [1]/[3]
# Image: [71]/[245]: Folder: [1]/[3]
# Image: [72]/[245]: Folder: [1]/[3]
# Image: [73]/[245]: Folder: [1]/[3]
# Image: [74]/[245]: Folder: [1]/[3]
# Image: [75]/[245]: Folder: [1]/[3]
# Image: [76]/[245]: Folder: [1]/[3]
# Image: [77]/[245]: Folder: [1]/[3]
# Image: [78]/[245]: Folder: [1]/[3]
# Image: [79]/[245]: Folder: [1]/[3]
# Image: [80]/[245]: Folder: [1]/[3]
# Image: [81]/[245]: Folder: [1]/[3]
# Image: [82]/[245]: Folder: [1]/[3]
# Image: [83]/[245]: Folder: [1]/[3]
# Image: [84]/[245]: Folder: [1]/[3]
# Image: [85]/[245]: Folder: [1]/[3]
# Image: [86]/[245]: Folder: [1]/[3]
# Image: [87]/[245]: Folder: [1]/[3]
# Image: [88]/[245]: Folder: [1]/[3]
# Image: [89]/[245]: Folder: [1]/[3]
# Image: [90]/[245]: Folder: [1]/[3]
# Image: [91]/[245]: Folder: [1]/[3]
# Image: [92]/[245]: Folder: [1]/[3]
# Image: [93]/[245]: Folder: [1]/[3]
# Image: [94]/[245]: Folder: [1]/[3]
# Image: [95]/[245]: Folder: [1]/[3]
# Image: [96]/[245]: Folder: [1]/[3]
# Image: [97]/[245]: Folder: [1]/[3]
# Image: [98]/[245]: Folder: [1]/[3]
# Image: [99]/[245]: Folder: [1]/[3]
# Image: [100]/[245]: Folder: [1]/[3]
# Image: [101]/[245]: Folder: [1]/[3]
# Image: [102]/[245]: Folder: [1]/[3]
# Image: [103]/[245]: Folder: [1]/[3]
# Image: [104]/[245]: Folder: [1]/[3]
# Image: [105]/[245]: Folder: [1]/[3]
# Image: [106]/[245]: Folder: [1]/[3]
# Image: [107]/[245]: Folder: [1]/[3]
# Image: [108]/[245]: Folder: [1]/[3]
# Image: [109]/[245]: Folder: [1]/[3]
# Image: [110]/[245]: Folder: [1]/[3]
# Image: [111]/[245]: Folder: [1]/[3]
# Image: [112]/[245]: Folder: [1]/[3]
# Image: [113]/[245]: Folder: [1]/[3]
# Image: [114]/[245]: Folder: [1]/[3]
# Image: [115]/[245]: Folder: [1]/[3]
# Image: [116]/[245]: Folder: [1]/[3]
# Image: [117]/[245]: Folder: [1]/[3]
# Image: [118]/[245]: Folder: [1]/[3]
# Image: [119]/[245]: Folder: [1]/[3]
# Image: [120]/[245]: Folder: [1]/[3]
# Image: [121]/[245]: Folder: [1]/[3]
# Image: [122]/[245]: Folder: [1]/[3]
# Image: [123]/[245]: Folder: [1]/[3]
# Image: [124]/[245]: Folder: [1]/[3]
# Image: [125]/[245]: Folder: [1]/[3]
# Image: [126]/[245]: Folder: [1]/[3]
# Image: [127]/[245]: Folder: [1]/[3]
# Image: [128]/[245]: Folder: [1]/[3]
# Image: [129]/[245]: Folder: [1]/[3]
# Image: [130]/[245]: Folder: [1]/[3]
# Image: [131]/[245]: Folder: [1]/[3]
# Image: [132]/[245]: Folder: [1]/[3]
# Image: [133]/[245]: Folder: [1]/[3]
# Image: [134]/[245]: Folder: [1]/[3]
# Image: [135]/[245]: Folder: [1]/[3]
# Image: [136]/[245]: Folder: [1]/[3]
# Image: [137]/[245]: Folder: [1]/[3]
# Image: [138]/[245]: Folder: [1]/[3]
# Image: [139]/[245]: Folder: [1]/[3]
# Image: [140]/[245]: Folder: [1]/[3]
# Image: [141]/[245]: Folder: [1]/[3]
# Image: [142]/[245]: Folder: [1]/[3]
# Image: [143]/[245]: Folder: [1]/[3]
# Image: [144]/[245]: Folder: [1]/[3]
# Image: [145]/[245]: Folder: [1]/[3]
# Image: [146]/[245]: Folder: [1]/[3]
# Image: [147]/[245]: Folder: [1]/[3]
# Image: [148]/[245]: Folder: [1]/[3]
# Image: [149]/[245]: Folder: [1]/[3]
# Image: [150]/[245]: Folder: [1]/[3]
# Image: [151]/[245]: Folder: [1]/[3]
# Image: [152]/[245]: Folder: [1]/[3]
# Image: [153]/[245]: Folder: [1]/[3]
# Image: [154]/[245]: Folder: [1]/[3]
# Image: [155]/[245]: Folder: [1]/[3]
# Image: [156]/[245]: Folder: [1]/[3]
# Image: [157]/[245]: Folder: [1]/[3]
# Image: [158]/[245]: Folder: [1]/[3]
# Image: [159]/[245]: Folder: [1]/[3]
# Image: [160]/[245]: Folder: [1]/[3]
# Image: [161]/[245]: Folder: [1]/[3]
# Image: [162]/[245]: Folder: [1]/[3]
# Image: [163]/[245]: Folder: [1]/[3]
# Image: [164]/[245]: Folder: [1]/[3]
# Image: [165]/[245]: Folder: [1]/[3]
# Image: [166]/[245]: Folder: [1]/[3]
# Image: [167]/[245]: Folder: [1]/[3]
# Image: [168]/[245]: Folder: [1]/[3]
# Image: [169]/[245]: Folder: [1]/[3]
# Image: [170]/[245]: Folder: [1]/[3]
# Image: [171]/[245]: Folder: [1]/[3]
# Image: [172]/[245]: Folder: [1]/[3]
# Image: [173]/[245]: Folder: [1]/[3]
# Image: [174]/[245]: Folder: [1]/[3]
# Image: [175]/[245]: Folder: [1]/[3]
# Image: [176]/[245]: Folder: [1]/[3]
# Image: [177]/[245]: Folder: [1]/[3]
# Image: [178]/[245]: Folder: [1]/[3]
# Image: [179]/[245]: Folder: [1]/[3]
# Image: [180]/[245]: Folder: [1]/[3]
# Image: [181]/[245]: Folder: [1]/[3]
# Image: [182]/[245]: Folder: [1]/[3]
# Image: [183]/[245]: Folder: [1]/[3]
# Image: [184]/[245]: Folder: [1]/[3]
# Image: [185]/[245]: Folder: [1]/[3]
# Image: [186]/[245]: Folder: [1]/[3]
# Image: [187]/[245]: Folder: [1]/[3]
# Image: [188]/[245]: Folder: [1]/[3]
# Image: [189]/[245]: Folder: [1]/[3]
# Image: [190]/[245]: Folder: [1]/[3]
# Image: [191]/[245]: Folder: [1]/[3]
# Image: [192]/[245]: Folder: [1]/[3]
# Image: [193]/[245]: Folder: [1]/[3]
# Image: [194]/[245]: Folder: [1]/[3]
# Image: [195]/[245]: Folder: [1]/[3]
# Image: [196]/[245]: Folder: [1]/[3]
# Image: [197]/[245]: Folder: [1]/[3]
# Image: [198]/[245]: Folder: [1]/[3]
# Image: [199]/[245]: Folder: [1]/[3]
# Image: [200]/[245]: Folder: [1]/[3]
# Image: [201]/[245]: Folder: [1]/[3]
# Image: [202]/[245]: Folder: [1]/[3]
# Image: [203]/[245]: Folder: [1]/[3]
# Image: [204]/[245]: Folder: [1]/[3]
# Image: [205]/[245]: Folder: [1]/[3]
# Image: [206]/[245]: Folder: [1]/[3]
# Image: [207]/[245]: Folder: [1]/[3]
# Image: [208]/[245]: Folder: [1]/[3]
# Image: [209]/[245]: Folder: [1]/[3]
# Image: [210]/[245]: Folder: [1]/[3]
# Image: [211]/[245]: Folder: [1]/[3]
# Image: [212]/[245]: Folder: [1]/[3]
# Image: [213]/[245]: Folder: [1]/[3]
# Image: [214]/[245]: Folder: [1]/[3]
# Image: [215]/[245]: Folder: [1]/[3]
# Image: [216]/[245]: Folder: [1]/[3]
# Image: [217]/[245]: Folder: [1]/[3]
# Image: [218]/[245]: Folder: [1]/[3]
# Image: [219]/[245]: Folder: [1]/[3]
# Image: [220]/[245]: Folder: [1]/[3]
# Image: [221]/[245]: Folder: [1]/[3]
# Image: [222]/[245]: Folder: [1]/[3]
# Image: [223]/[245]: Folder: [1]/[3]
# Image: [224]/[245]: Folder: [1]/[3]
# Image: [225]/[245]: Folder: [1]/[3]
# Image: [226]/[245]: Folder: [1]/[3]
# Image: [227]/[245]: Folder: [1]/[3]
# Image: [228]/[245]: Folder: [1]/[3]
# Image: [229]/[245]: Folder: [1]/[3]
# Image: [230]/[245]: Folder: [1]/[3]
# Image: [231]/[245]: Folder: [1]/[3]
# Image: [232]/[245]: Folder: [1]/[3]
# Image: [233]/[245]: Folder: [1]/[3]
# Image: [234]/[245]: Folder: [1]/[3]
# Image: [235]/[245]: Folder: [1]/[3]
# Image: [236]/[245]: Folder: [1]/[3]
# Image: [237]/[245]: Folder: [1]/[3]
# Image: [238]/[245]: Folder: [1]/[3]
# Image: [239]/[245]: Folder: [1]/[3]
# Image: [240]/[245]: Folder: [1]/[3]
# Image: [241]/[245]: Folder: [1]/[3]
# Image: [242]/[245]: Folder: [1]/[3]
# Image: [243]/[245]: Folder: [1]/[3]
# Image: [244]/[245]: Folder: [1]/[3]
# Image: [245]/[245]: Folder: [1]/[3]
# Image: [1]/[62]: Folder: [2]/[3]
# Image: [2]/[62]: Folder: [2]/[3]
# Image: [3]/[62]: Folder: [2]/[3]
# Image: [4]/[62]: Folder: [2]/[3]
# Image: [5]/[62]: Folder: [2]/[3]
# Image: [6]/[62]: Folder: [2]/[3]
# Image: [7]/[62]: Folder: [2]/[3]
# Image: [8]/[62]: Folder: [2]/[3]
# Image: [9]/[62]: Folder: [2]/[3]
# Image: [10]/[62]: Folder: [2]/[3]
# Image: [11]/[62]: Folder: [2]/[3]
# Image: [12]/[62]: Folder: [2]/[3]
# Image: [13]/[62]: Folder: [2]/[3]
# Image: [14]/[62]: Folder: [2]/[3]
# Image: [15]/[62]: Folder: [2]/[3]
# Image: [16]/[62]: Folder: [2]/[3]
# Image: [17]/[62]: Folder: [2]/[3]
# Image: [18]/[62]: Folder: [2]/[3]
# Image: [19]/[62]: Folder: [2]/[3]
# Image: [20]/[62]: Folder: [2]/[3]
# Image: [21]/[62]: Folder: [2]/[3]
# Image: [22]/[62]: Folder: [2]/[3]
# Image: [23]/[62]: Folder: [2]/[3]
# Image: [24]/[62]: Folder: [2]/[3]
# Image: [25]/[62]: Folder: [2]/[3]
# Image: [26]/[62]: Folder: [2]/[3]
# Image: [27]/[62]: Folder: [2]/[3]
# Image: [28]/[62]: Folder: [2]/[3]
# Image: [29]/[62]: Folder: [2]/[3]
# Image: [30]/[62]: Folder: [2]/[3]
# Image: [31]/[62]: Folder: [2]/[3]
# Image: [32]/[62]: Folder: [2]/[3]
# Image: [33]/[62]: Folder: [2]/[3]
# Image: [34]/[62]: Folder: [2]/[3]
# Image: [35]/[62]: Folder: [2]/[3]
# Image: [36]/[62]: Folder: [2]/[3]
# Image: [37]/[62]: Folder: [2]/[3]
# Image: [38]/[62]: Folder: [2]/[3]
# Image: [39]/[62]: Folder: [2]/[3]
# Image: [40]/[62]: Folder: [2]/[3]
# Image: [41]/[62]: Folder: [2]/[3]
# Image: [42]/[62]: Folder: [2]/[3]
# Image: [43]/[62]: Folder: [2]/[3]
# Image: [44]/[62]: Folder: [2]/[3]
# Image: [45]/[62]: Folder: [2]/[3]
# Image: [46]/[62]: Folder: [2]/[3]
# Image: [47]/[62]: Folder: [2]/[3]
# Image: [48]/[62]: Folder: [2]/[3]
# Image: [49]/[62]: Folder: [2]/[3]
# Image: [50]/[62]: Folder: [2]/[3]
# Image: [51]/[62]: Folder: [2]/[3]
# Image: [52]/[62]: Folder: [2]/[3]
# Image: [53]/[62]: Folder: [2]/[3]
# Image: [54]/[62]: Folder: [2]/[3]
# Image: [55]/[62]: Folder: [2]/[3]
# Image: [56]/[62]: Folder: [2]/[3]
# Image: [57]/[62]: Folder: [2]/[3]
# Image: [58]/[62]: Folder: [2]/[3]
# Image: [59]/[62]: Folder: [2]/[3]
# Image: [60]/[62]: Folder: [2]/[3]
# Image: [61]/[62]: Folder: [2]/[3]
# Image: [62]/[62]: Folder: [2]/[3]
# Image: [1]/[307]: Folder: [3]/[3]
# Image: [2]/[307]: Folder: [3]/[3]
# Image: [3]/[307]: Folder: [3]/[3]
# Image: [4]/[307]: Folder: [3]/[3]
# Image: [5]/[307]: Folder: [3]/[3]
# Image: [6]/[307]: Folder: [3]/[3]
# Image: [7]/[307]: Folder: [3]/[3]
# Image: [8]/[307]: Folder: [3]/[3]
# Image: [9]/[307]: Folder: [3]/[3]
# Image: [10]/[307]: Folder: [3]/[3]
# Image: [11]/[307]: Folder: [3]/[3]
# Image: [12]/[307]: Folder: [3]/[3]
# Image: [13]/[307]: Folder: [3]/[3]
# Image: [14]/[307]: Folder: [3]/[3]
# Image: [15]/[307]: Folder: [3]/[3]
# Image: [16]/[307]: Folder: [3]/[3]
# Image: [17]/[307]: Folder: [3]/[3]
# Image: [18]/[307]: Folder: [3]/[3]
# Image: [19]/[307]: Folder: [3]/[3]
# Image: [20]/[307]: Folder: [3]/[3]
# Image: [21]/[307]: Folder: [3]/[3]
# Image: [22]/[307]: Folder: [3]/[3]
# Image: [23]/[307]: Folder: [3]/[3]
# Image: [24]/[307]: Folder: [3]/[3]
# Image: [25]/[307]: Folder: [3]/[3]
# Image: [26]/[307]: Folder: [3]/[3]
# Image: [27]/[307]: Folder: [3]/[3]
# Image: [28]/[307]: Folder: [3]/[3]
# Image: [29]/[307]: Folder: [3]/[3]
# Image: [30]/[307]: Folder: [3]/[3]
# Image: [31]/[307]: Folder: [3]/[3]
# Image: [32]/[307]: Folder: [3]/[3]
# Image: [33]/[307]: Folder: [3]/[3]
# Image: [34]/[307]: Folder: [3]/[3]
# Image: [35]/[307]: Folder: [3]/[3]
# Image: [36]/[307]: Folder: [3]/[3]
# Image: [37]/[307]: Folder: [3]/[3]
# Image: [38]/[307]: Folder: [3]/[3]
# Image: [39]/[307]: Folder: [3]/[3]
# Image: [40]/[307]: Folder: [3]/[3]
# Image: [41]/[307]: Folder: [3]/[3]
# Image: [42]/[307]: Folder: [3]/[3]
# Image: [43]/[307]: Folder: [3]/[3]
# Image: [44]/[307]: Folder: [3]/[3]
# Image: [45]/[307]: Folder: [3]/[3]
# Image: [46]/[307]: Folder: [3]/[3]
# Image: [47]/[307]: Folder: [3]/[3]
# Image: [48]/[307]: Folder: [3]/[3]
# Image: [49]/[307]: Folder: [3]/[3]
# Image: [50]/[307]: Folder: [3]/[3]
# Image: [51]/[307]: Folder: [3]/[3]
# Image: [52]/[307]: Folder: [3]/[3]
# Image: [53]/[307]: Folder: [3]/[3]
# Image: [54]/[307]: Folder: [3]/[3]
# Image: [55]/[307]: Folder: [3]/[3]
# Image: [56]/[307]: Folder: [3]/[3]
# Image: [57]/[307]: Folder: [3]/[3]
# Image: [58]/[307]: Folder: [3]/[3]
# Image: [59]/[307]: Folder: [3]/[3]
# Image: [60]/[307]: Folder: [3]/[3]
# Image: [61]/[307]: Folder: [3]/[3]
# Image: [62]/[307]: Folder: [3]/[3]
# Image: [63]/[307]: Folder: [3]/[3]
# Image: [64]/[307]: Folder: [3]/[3]
# Image: [65]/[307]: Folder: [3]/[3]
# Image: [66]/[307]: Folder: [3]/[3]
# Image: [67]/[307]: Folder: [3]/[3]
# Image: [68]/[307]: Folder: [3]/[3]
# Image: [69]/[307]: Folder: [3]/[3]
# Image: [70]/[307]: Folder: [3]/[3]
# Image: [71]/[307]: Folder: [3]/[3]
# Image: [72]/[307]: Folder: [3]/[3]
# Image: [73]/[307]: Folder: [3]/[3]
# Image: [74]/[307]: Folder: [3]/[3]
# Image: [75]/[307]: Folder: [3]/[3]
# Image: [76]/[307]: Folder: [3]/[3]
# Image: [77]/[307]: Folder: [3]/[3]
# Image: [78]/[307]: Folder: [3]/[3]
# Image: [79]/[307]: Folder: [3]/[3]
# Image: [80]/[307]: Folder: [3]/[3]
# Image: [81]/[307]: Folder: [3]/[3]
# Image: [82]/[307]: Folder: [3]/[3]
# Image: [83]/[307]: Folder: [3]/[3]
# Image: [84]/[307]: Folder: [3]/[3]
# Image: [85]/[307]: Folder: [3]/[3]
# Image: [86]/[307]: Folder: [3]/[3]
# Image: [87]/[307]: Folder: [3]/[3]
# Image: [88]/[307]: Folder: [3]/[3]
# Image: [89]/[307]: Folder: [3]/[3]
# Image: [90]/[307]: Folder: [3]/[3]
# Image: [91]/[307]: Folder: [3]/[3]
# Image: [92]/[307]: Folder: [3]/[3]
# Image: [93]/[307]: Folder: [3]/[3]
# Image: [94]/[307]: Folder: [3]/[3]
# Image: [95]/[307]: Folder: [3]/[3]
# Image: [96]/[307]: Folder: [3]/[3]
# Image: [97]/[307]: Folder: [3]/[3]
# Image: [98]/[307]: Folder: [3]/[3]
# Image: [99]/[307]: Folder: [3]/[3]
# Image: [100]/[307]: Folder: [3]/[3]
# Image: [101]/[307]: Folder: [3]/[3]
# Image: [102]/[307]: Folder: [3]/[3]
# Image: [103]/[307]: Folder: [3]/[3]
# Image: [104]/[307]: Folder: [3]/[3]
# Image: [105]/[307]: Folder: [3]/[3]
# Image: [106]/[307]: Folder: [3]/[3]
# Image: [107]/[307]: Folder: [3]/[3]
# Image: [108]/[307]: Folder: [3]/[3]
# Image: [109]/[307]: Folder: [3]/[3]
# Image: [110]/[307]: Folder: [3]/[3]
# Image: [111]/[307]: Folder: [3]/[3]
# Image: [112]/[307]: Folder: [3]/[3]
# Image: [113]/[307]: Folder: [3]/[3]
# Image: [114]/[307]: Folder: [3]/[3]
# Image: [115]/[307]: Folder: [3]/[3]
# Image: [116]/[307]: Folder: [3]/[3]
# Image: [117]/[307]: Folder: [3]/[3]
# Image: [118]/[307]: Folder: [3]/[3]
# Image: [119]/[307]: Folder: [3]/[3]
# Image: [120]/[307]: Folder: [3]/[3]
# Image: [121]/[307]: Folder: [3]/[3]
# Image: [122]/[307]: Folder: [3]/[3]
# Image: [123]/[307]: Folder: [3]/[3]
# Image: [124]/[307]: Folder: [3]/[3]
# Image: [125]/[307]: Folder: [3]/[3]
# Image: [126]/[307]: Folder: [3]/[3]
# Image: [127]/[307]: Folder: [3]/[3]
# Image: [128]/[307]: Folder: [3]/[3]
# Image: [129]/[307]: Folder: [3]/[3]
# Image: [130]/[307]: Folder: [3]/[3]
# Image: [131]/[307]: Folder: [3]/[3]
# Image: [132]/[307]: Folder: [3]/[3]
# Image: [133]/[307]: Folder: [3]/[3]
# Image: [134]/[307]: Folder: [3]/[3]
# Image: [135]/[307]: Folder: [3]/[3]
# Image: [136]/[307]: Folder: [3]/[3]
# Image: [137]/[307]: Folder: [3]/[3]
# Image: [138]/[307]: Folder: [3]/[3]
# Image: [139]/[307]: Folder: [3]/[3]
# Image: [140]/[307]: Folder: [3]/[3]
# Image: [141]/[307]: Folder: [3]/[3]
# Image: [142]/[307]: Folder: [3]/[3]
# Image: [143]/[307]: Folder: [3]/[3]
# Image: [144]/[307]: Folder: [3]/[3]
# Image: [145]/[307]: Folder: [3]/[3]
# Image: [146]/[307]: Folder: [3]/[3]
# Image: [147]/[307]: Folder: [3]/[3]
# Image: [148]/[307]: Folder: [3]/[3]
# Image: [149]/[307]: Folder: [3]/[3]
# Image: [150]/[307]: Folder: [3]/[3]
# Image: [151]/[307]: Folder: [3]/[3]
# Image: [152]/[307]: Folder: [3]/[3]
# Image: [153]/[307]: Folder: [3]/[3]
# Image: [154]/[307]: Folder: [3]/[3]
# Image: [155]/[307]: Folder: [3]/[3]
# Image: [156]/[307]: Folder: [3]/[3]
# Image: [157]/[307]: Folder: [3]/[3]
# Image: [158]/[307]: Folder: [3]/[3]
# Image: [159]/[307]: Folder: [3]/[3]
# Image: [160]/[307]: Folder: [3]/[3]
# Image: [161]/[307]: Folder: [3]/[3]
# Image: [162]/[307]: Folder: [3]/[3]
# Image: [163]/[307]: Folder: [3]/[3]
# Image: [164]/[307]: Folder: [3]/[3]
# Image: [165]/[307]: Folder: [3]/[3]
# Image: [166]/[307]: Folder: [3]/[3]
# Image: [167]/[307]: Folder: [3]/[3]
# Image: [168]/[307]: Folder: [3]/[3]
# Image: [169]/[307]: Folder: [3]/[3]
# Image: [170]/[307]: Folder: [3]/[3]
# Image: [171]/[307]: Folder: [3]/[3]
# Image: [172]/[307]: Folder: [3]/[3]
# Image: [173]/[307]: Folder: [3]/[3]
# Image: [174]/[307]: Folder: [3]/[3]
# Image: [175]/[307]: Folder: [3]/[3]
# Image: [176]/[307]: Folder: [3]/[3]
# Image: [177]/[307]: Folder: [3]/[3]
# Image: [178]/[307]: Folder: [3]/[3]
# Image: [179]/[307]: Folder: [3]/[3]
# Image: [180]/[307]: Folder: [3]/[3]
# Image: [181]/[307]: Folder: [3]/[3]
# Image: [182]/[307]: Folder: [3]/[3]
# Image: [183]/[307]: Folder: [3]/[3]
# Image: [184]/[307]: Folder: [3]/[3]
# Image: [185]/[307]: Folder: [3]/[3]
# Image: [186]/[307]: Folder: [3]/[3]
# Image: [187]/[307]: Folder: [3]/[3]
# Image: [188]/[307]: Folder: [3]/[3]
# Image: [189]/[307]: Folder: [3]/[3]
# Image: [190]/[307]: Folder: [3]/[3]
# Image: [191]/[307]: Folder: [3]/[3]
# Image: [192]/[307]: Folder: [3]/[3]
# Image: [193]/[307]: Folder: [3]/[3]
# Image: [194]/[307]: Folder: [3]/[3]
# Image: [195]/[307]: Folder: [3]/[3]
# Image: [196]/[307]: Folder: [3]/[3]
# Image: [197]/[307]: Folder: [3]/[3]
# Image: [198]/[307]: Folder: [3]/[3]
# Image: [199]/[307]: Folder: [3]/[3]
# Image: [200]/[307]: Folder: [3]/[3]
# Image: [201]/[307]: Folder: [3]/[3]
# Image: [202]/[307]: Folder: [3]/[3]
# Image: [203]/[307]: Folder: [3]/[3]
# Image: [204]/[307]: Folder: [3]/[3]
# Image: [205]/[307]: Folder: [3]/[3]
# Image: [206]/[307]: Folder: [3]/[3]
# Image: [207]/[307]: Folder: [3]/[3]
# Image: [208]/[307]: Folder: [3]/[3]
# Image: [209]/[307]: Folder: [3]/[3]
# Image: [210]/[307]: Folder: [3]/[3]
# Image: [211]/[307]: Folder: [3]/[3]
# Image: [212]/[307]: Folder: [3]/[3]
# Image: [213]/[307]: Folder: [3]/[3]
# Image: [214]/[307]: Folder: [3]/[3]
# Image: [215]/[307]: Folder: [3]/[3]
# Image: [216]/[307]: Folder: [3]/[3]
# Image: [217]/[307]: Folder: [3]/[3]
# Image: [218]/[307]: Folder: [3]/[3]
# Image: [219]/[307]: Folder: [3]/[3]
# Image: [220]/[307]: Folder: [3]/[3]
# Image: [221]/[307]: Folder: [3]/[3]
# Image: [222]/[307]: Folder: [3]/[3]
# Image: [223]/[307]: Folder: [3]/[3]
# Image: [224]/[307]: Folder: [3]/[3]
# Image: [225]/[307]: Folder: [3]/[3]
# Image: [226]/[307]: Folder: [3]/[3]
# Image: [227]/[307]: Folder: [3]/[3]
# Image: [228]/[307]: Folder: [3]/[3]
# Image: [229]/[307]: Folder: [3]/[3]
# Image: [230]/[307]: Folder: [3]/[3]
# Image: [231]/[307]: Folder: [3]/[3]
# Image: [232]/[307]: Folder: [3]/[3]
# Image: [233]/[307]: Folder: [3]/[3]
# Image: [234]/[307]: Folder: [3]/[3]
# Image: [235]/[307]: Folder: [3]/[3]
# Image: [236]/[307]: Folder: [3]/[3]
# Image: [237]/[307]: Folder: [3]/[3]
# Image: [238]/[307]: Folder: [3]/[3]
# Image: [239]/[307]: Folder: [3]/[3]
# Image: [240]/[307]: Folder: [3]/[3]
# Image: [241]/[307]: Folder: [3]/[3]
# Image: [242]/[307]: Folder: [3]/[3]
# Image: [243]/[307]: Folder: [3]/[3]
# Image: [244]/[307]: Folder: [3]/[3]
# Image: [245]/[307]: Folder: [3]/[3]
# Image: [246]/[307]: Folder: [3]/[3]
# Image: [247]/[307]: Folder: [3]/[3]
# Image: [248]/[307]: Folder: [3]/[3]
# Image: [249]/[307]: Folder: [3]/[3]
# Image: [250]/[307]: Folder: [3]/[3]
# Image: [251]/[307]: Folder: [3]/[3]
# Image: [252]/[307]: Folder: [3]/[3]
# Image: [253]/[307]: Folder: [3]/[3]
# Image: [254]/[307]: Folder: [3]/[3]
# Image: [255]/[307]: Folder: [3]/[3]
# Image: [256]/[307]: Folder: [3]/[3]
# Image: [257]/[307]: Folder: [3]/[3]
# Image: [258]/[307]: Folder: [3]/[3]
# Image: [259]/[307]: Folder: [3]/[3]
# Image: [260]/[307]: Folder: [3]/[3]
# Image: [261]/[307]: Folder: [3]/[3]
# Image: [262]/[307]: Folder: [3]/[3]
# Image: [263]/[307]: Folder: [3]/[3]
# Image: [264]/[307]: Folder: [3]/[3]
# Image: [265]/[307]: Folder: [3]/[3]
# Image: [266]/[307]: Folder: [3]/[3]
# Image: [267]/[307]: Folder: [3]/[3]
# Image: [268]/[307]: Folder: [3]/[3]
# Image: [269]/[307]: Folder: [3]/[3]
# Image: [270]/[307]: Folder: [3]/[3]
# Image: [271]/[307]: Folder: [3]/[3]
# Image: [272]/[307]: Folder: [3]/[3]
# Image: [273]/[307]: Folder: [3]/[3]
# Image: [274]/[307]: Folder: [3]/[3]
# Image: [275]/[307]: Folder: [3]/[3]
# Image: [276]/[307]: Folder: [3]/[3]
# Image: [277]/[307]: Folder: [3]/[3]
# Image: [278]/[307]: Folder: [3]/[3]
# Image: [279]/[307]: Folder: [3]/[3]
# Image: [280]/[307]: Folder: [3]/[3]
# Image: [281]/[307]: Folder: [3]/[3]
# Image: [282]/[307]: Folder: [3]/[3]
# Image: [283]/[307]: Folder: [3]/[3]
# Image: [284]/[307]: Folder: [3]/[3]
# Image: [285]/[307]: Folder: [3]/[3]
# Image: [286]/[307]: Folder: [3]/[3]
# Image: [287]/[307]: Folder: [3]/[3]
# Image: [288]/[307]: Folder: [3]/[3]
# Image: [289]/[307]: Folder: [3]/[3]
# Image: [290]/[307]: Folder: [3]/[3]
# Image: [291]/[307]: Folder: [3]/[3]
# Image: [292]/[307]: Folder: [3]/[3]
# Image: [293]/[307]: Folder: [3]/[3]
# Image: [294]/[307]: Folder: [3]/[3]
# Image: [295]/[307]: Folder: [3]/[3]
# Image: [296]/[307]: Folder: [3]/[3]
# Image: [297]/[307]: Folder: [3]/[3]
# Image: [298]/[307]: Folder: [3]/[3]
# Image: [299]/[307]: Folder: [3]/[3]
# Image: [300]/[307]: Folder: [3]/[3]
# Image: [301]/[307]: Folder: [3]/[3]
# Image: [302]/[307]: Folder: [3]/[3]
# Image: [303]/[307]: Folder: [3]/[3]
# Image: [304]/[307]: Folder: [3]/[3]
# Image: [305]/[307]: Folder: [3]/[3]
# Image: [306]/[307]: Folder: [3]/[3]
# Image: [307]/[307]: Folder: [3]/[3]
